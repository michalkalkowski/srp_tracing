# %% [markdown]
# ## Load data files

# %%
rt = np.load('../tests/raytracer_ogilvy.npy')*1e6
fe_01 = np.load('../data/fe_ogilvy/tofs_01.npy')*1e6
fe_05 = np.load('../data/fe_ogilvy/tofs_05.npy')*1e6
fe_025 = np.load('../data/fe_ogilvy/tofs_025.npy')*1e6
fe_025_1M = np.load('../data/fe_ogilvy/tofs_025_1mhz.npy')*1e6 - 0.75 # wrong correction applied at tof extraction
fe_025_inv = np.load('../data/fe_ogilvy/tofs_025_inv.npy')*1e6

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# %run ../tests/validation_ogilvy.py
# Out:
# ------Ogilvy model setup------
# Tangent parameter T: 1
# Rate of change along the z-axis: 1
# Weld thickness: 55
# Chamfer base: 4.5
# Chamfer top: 39
# ----------------------------
# /media/michal/MKK_data/mCloud/projects/ADVISE/ogilvy_weld/ogilvy/ogilvy_model.py:150: RuntimeWarning: divide by zero encountered in true_divide
#   self.mesh_y*np.tan(self.alpha))/abs(self.mesh_x)**self.n_weld)
# /media/michal/MKK_data/mCloud/projects/ADVISE/ogilvy_weld/ogilvy/ogilvy_model.py:164: RuntimeWarning: invalid value encountered in less
#   self.grain_orientations[self.grain_orientations < -np.pi/2] += np.pi
# /media/michal/MKK_data/mCloud/projects/ADVISE/ogilvy_weld/ogilvy/ogilvy_model.py:165: RuntimeWarning: invalid value encountered in greater
#   self.grain_orientations[self.grain_orientations > np.pi/2] -= np.pi
# 100%|██████████| 20630/20630 [00:01<00:00, 20113.91it/s]

# %%
plt.plot(rt, label='raytracer')
plt.plot(time_srp*1e6, label='SRP')
plt.plot(fe_01, label='FE 0.1 mm')
plt.plot(fe_05, label='FE 0.05 mm')
plt.plot(fe_025, label='FE 0.025 mm')
plt.plot(fe_025_1M, label='FE 0.025 mm, 1 MHz')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %% [markdown]
# # Why are these different??!!
